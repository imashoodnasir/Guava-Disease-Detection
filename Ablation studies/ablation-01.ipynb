# %% [markdown]
# ## N3 Classifier

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
# Define paths
train_dir = '/kaggle/input/guava-fruit-disease-dataset/Guava Fruit Disease Dataset/GuavaDiseaseDataset/GuavaDiseaseDataset/train'
test_dir = '/kaggle/input/guava-fruit-disease-dataset/Guava Fruit Disease Dataset/GuavaDiseaseDataset/GuavaDiseaseDataset/test'
val_dir = '/kaggle/input/guava-fruit-disease-dataset/Guava Fruit Disease Dataset/GuavaDiseaseDataset/GuavaDiseaseDataset/val'

# Image dimensions
img_height = 224
img_width = 224
batch_size = 32
# Function to count images in each class
def count_images(directory):
    classes = ['Anthracnose', 'fruit_fly', 'healthy_guava']
    counts = {}
    for class_name in classes:
        class_dir = os.path.join(directory, class_name)
        counts[class_name] = len(os.listdir(class_dir))
    return counts

# Count images in train, test, and validation sets
train_counts = count_images(train_dir)
test_counts = count_images(test_dir)
val_counts = count_images(val_dir)

# Print the counts
print("Training set counts:", train_counts)
print("Validation set counts:", val_counts)
print("Test set counts:", test_counts)

# Plot bar chart for training set
plt.bar(train_counts.keys(), train_counts.values())
plt.title('Training Data Distribution')
plt.xlabel('Classes')
plt.ylabel('Number of Images')
plt.show()
# Data generators
train_datagen = ImageDataGenerator(rescale=1./255)

test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(train_dir,
                                                    target_size=(img_height, img_width),
                                                    batch_size=batch_size,
                                                    class_mode='categorical')

validation_generator = test_datagen.flow_from_directory(val_dir,
                                                        target_size=(img_height, img_width),
                                                        batch_size=batch_size,
                                                        class_mode='categorical')

test_generator = test_datagen.flow_from_directory(test_dir,
                                                  target_size=(img_height, img_width),
                                                  batch_size=batch_size,
                                                  class_mode='categorical',
                                                  shuffle=False)
# Define a custom CNN block with fusion of DenseNet and Residual connections
def custom_cnn_block(x, filters):
    input_tensor = x
    # DenseNet-like block
    x1 = layers.Conv2D(filters, (1,1), padding='same', activation='relu')(x)
    x1 = layers.Conv2D(filters, (3,3), padding='same', activation='relu')(x1)
    
    x2 = layers.Conv2D(filters, (1,1), padding='same', activation='relu')(x)
    x2 = layers.Conv2D(filters, (5,5), padding='same', activation='relu')(x2)
    
    x = layers.Concatenate()([x1, x2])
    x = layers.Conv2D(filters, (1,1), padding='same', activation='relu')(x)  # Bottleneck layer
    
    # Residual connection
    shortcut = layers.Conv2D(filters, (1,1), padding='same')(input_tensor)
    x = layers.Add()([x, shortcut])
    x = layers.Activation('relu')(x)
    return x

# Build the model using Functional API
inputs = layers.Input(shape=(img_height, img_width, 3))

# Initial layers
x = layers.Conv2D(32, (3,3), activation='relu', padding='same')(inputs)
x = layers.Conv2D(32, (3,3), activation='relu', padding='same')(x)
x = layers.MaxPooling2D(pool_size=(2,2))(x)

x = inputs
# Custom CNN blocks with increasing filters
x = custom_cnn_block(x, 64)
x = layers.MaxPooling2D(pool_size=(2,2))(x)

x = custom_cnn_block(x, 128)
x = layers.MaxPooling2D(pool_size=(2,2))(x)

# x = custom_cnn_block(x, 256)
# x = layers.MaxPooling2D(pool_size=(2,2))(x)


x = layers.GlobalAveragePooling2D()(x)
x = layers.Dense(256, activation='relu')(x)
x = layers.Dense(128, activation='relu')(x)
x = layers.Dense(64, activation='relu')(x)
# Output layer
outputs = layers.Dense(3, activation='softmax')(x)

# Create the model
model = models.Model(inputs=inputs, outputs=outputs)

# Compile the model
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Print model summary
model.summary()
# Callbacks
early_stopping = tf.keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True, verbose=1)
checkpoint = tf.keras.callbacks.ModelCheckpoint('best_model.keras', save_best_only=True, monitor='val_loss')
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(factor=0.1, patience=5, min_lr=0.00001)

# Train the model
history = model.fit(train_generator,
                    epochs=10,
                    validation_data=validation_generator,
                    callbacks=[early_stopping, checkpoint, reduce_lr])
# Evaluate on test set
test_loss, test_accuracy = model.evaluate(test_generator)
print(f'Test Accuracy: {test_accuracy:.4f}')

# Predictions
predictions = model.predict(test_generator)
predicted_classes = np.argmax(predictions, axis=1)

# Get true classes
true_classes = test_generator.classes

# Classification report
print('Classification Report:')
print(classification_report(true_classes, predicted_classes, target_names=test_generator.class_indices.keys()))

# Confusion matrix
cm = confusion_matrix(true_classes, predicted_classes)
plt.figure(figsize=(8,6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=test_generator.class_indices.keys(),
            yticklabels=test_generator.class_indices.keys())
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()
# Plot accuracy
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# Plot loss
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# Training set counts: {'Anthracnose': 1080, 'fruit_fly': 918, 'healthy_guava': 649}
# Validation set counts: {'Anthracnose': 308, 'fruit_fly': 262, 'healthy_guava': 185}
# Test set counts: {'Anthracnose': 156, 'fruit_fly': 132, 'healthy_guava': 94}
# Found 2647 images belonging to 3 classes.
# Found 755 images belonging to 3 classes.
# Found 382 images belonging to 3 classes.
# Model: "functional_21"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_12      │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_163 (Conv2D) │ (None, 224, 224,  │        256 │ input_layer_12[0… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_165 (Conv2D) │ (None, 224, 224,  │        256 │ input_layer_12[0… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_164 (Conv2D) │ (None, 224, 224,  │     36,928 │ conv2d_163[0][0]  │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_166 (Conv2D) │ (None, 224, 224,  │    102,464 │ conv2d_165[0][0]  │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_26      │ (None, 224, 224,  │          0 │ conv2d_164[0][0], │
# │ (Concatenate)       │ 128)              │            │ conv2d_166[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_167 (Conv2D) │ (None, 224, 224,  │      8,256 │ concatenate_26[0… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_168 (Conv2D) │ (None, 224, 224,  │        256 │ input_layer_12[0… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_26 (Add)        │ (None, 224, 224,  │          0 │ conv2d_167[0][0], │
# │                     │ 64)               │            │ conv2d_168[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_26       │ (None, 224, 224,  │          0 │ add_26[0][0]      │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_29    │ (None, 112, 112,  │          0 │ activation_26[0]… │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_169 (Conv2D) │ (None, 112, 112,  │      8,320 │ max_pooling2d_29… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_171 (Conv2D) │ (None, 112, 112,  │      8,320 │ max_pooling2d_29… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_170 (Conv2D) │ (None, 112, 112,  │    147,584 │ conv2d_169[0][0]  │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_172 (Conv2D) │ (None, 112, 112,  │    409,728 │ conv2d_171[0][0]  │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_27      │ (None, 112, 112,  │          0 │ conv2d_170[0][0], │
# │ (Concatenate)       │ 256)              │            │ conv2d_172[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_173 (Conv2D) │ (None, 112, 112,  │     32,896 │ concatenate_27[0… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_174 (Conv2D) │ (None, 112, 112,  │      8,320 │ max_pooling2d_29… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_27 (Add)        │ (None, 112, 112,  │          0 │ conv2d_173[0][0], │
# │                     │ 128)              │            │ conv2d_174[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_27       │ (None, 112, 112,  │          0 │ add_27[0][0]      │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_30    │ (None, 56, 56,    │          0 │ activation_27[0]… │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 128)       │          0 │ max_pooling2d_30… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_34 (Dense)    │ (None, 256)       │     33,024 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_35 (Dense)    │ (None, 128)       │     32,896 │ dense_34[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_36 (Dense)    │ (None, 64)        │      8,256 │ dense_35[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_37 (Dense)    │ (None, 3)         │        195 │ dense_36[0][0]    │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 837,955 (3.20 MB)
#  Trainable params: 837,955 (3.20 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/10
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 36s 360ms/step - accuracy: 0.3973 - loss: 1.0119 - val_accuracy: 0.7020 - val_loss: 0.6039 - learning_rate: 0.0010
# Epoch 2/10
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 29s 324ms/step - accuracy: 0.6597 - loss: 0.6613 - val_accuracy: 0.7960 - val_loss: 0.5101 - learning_rate: 0.0010
# Epoch 3/10
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 28s 316ms/step - accuracy: 0.8200 - loss: 0.4220 - val_accuracy: 0.8623 - val_loss: 0.3470 - learning_rate: 0.0010
# Epoch 4/10
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 29s 324ms/step - accuracy: 0.8860 - loss: 0.2801 - val_accuracy: 0.9060 - val_loss: 0.2333 - learning_rate: 0.0010
# Epoch 5/10
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 28s 318ms/step - accuracy: 0.9217 - loss: 0.1991 - val_accuracy: 0.9073 - val_loss: 0.2121 - learning_rate: 0.0010
# Epoch 6/10
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 28s 322ms/step - accuracy: 0.9366 - loss: 0.1714 - val_accuracy: 0.8821 - val_loss: 0.3598 - learning_rate: 0.0010
# Epoch 7/10
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 28s 312ms/step - accuracy: 0.9163 - loss: 0.2407 - val_accuracy: 0.9669 - val_loss: 0.1102 - learning_rate: 0.0010
# Epoch 8/10
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 29s 322ms/step - accuracy: 0.9569 - loss: 0.1178 - val_accuracy: 0.9576 - val_loss: 0.1286 - learning_rate: 0.0010
# Epoch 9/10
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 27s 304ms/step - accuracy: 0.9528 - loss: 0.1201 - val_accuracy: 0.9285 - val_loss: 0.1602 - learning_rate: 0.0010
# Epoch 10/10
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 28s 311ms/step - accuracy: 0.9552 - loss: 0.1124 - val_accuracy: 0.9603 - val_loss: 0.0965 - learning_rate: 0.0010
# Restoring model weights from the end of the best epoch: 10.
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 288ms/step - accuracy: 0.9475 - loss: 0.1446
# Test Accuracy: 0.9581
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 263ms/step
# Classification Report:
#                precision    recall  f1-score   support
#
#   Anthracnose       0.99      0.94      0.97       156
#     fruit_fly       0.90      0.98      0.94       132
# healthy_guava       0.99      0.95      0.97        94
#
#      accuracy                           0.96       382
#     macro avg       0.96      0.96      0.96       382
#  weighted avg       0.96      0.96      0.96       382

# %% [markdown]
# ## WN2 CLassifier

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
# Define paths
train_dir = '/kaggle/input/guava-fruit-disease-dataset/Guava Fruit Disease Dataset/GuavaDiseaseDataset/GuavaDiseaseDataset/train'
test_dir = '/kaggle/input/guava-fruit-disease-dataset/Guava Fruit Disease Dataset/GuavaDiseaseDataset/GuavaDiseaseDataset/test'
val_dir = '/kaggle/input/guava-fruit-disease-dataset/Guava Fruit Disease Dataset/GuavaDiseaseDataset/GuavaDiseaseDataset/val'

# Image dimensions
img_height = 224
img_width = 224
batch_size = 32
# Function to count images in each class
def count_images(directory):
    classes = ['Anthracnose', 'fruit_fly', 'healthy_guava']
    counts = {}
    for class_name in classes:
        class_dir = os.path.join(directory, class_name)
        counts[class_name] = len(os.listdir(class_dir))
    return counts

# Count images in train, test, and validation sets
train_counts = count_images(train_dir)
test_counts = count_images(test_dir)
val_counts = count_images(val_dir)

# Print the counts
print("Training set counts:", train_counts)
print("Validation set counts:", val_counts)
print("Test set counts:", test_counts)

# Plot bar chart for training set
plt.bar(train_counts.keys(), train_counts.values())
plt.title('Training Data Distribution')
plt.xlabel('Classes')
plt.ylabel('Number of Images')
plt.show()
# Data generators
train_datagen = ImageDataGenerator(rescale=1./255)

test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(train_dir,
                                                    target_size=(img_height, img_width),
                                                    batch_size=batch_size,
                                                    class_mode='categorical')

validation_generator = test_datagen.flow_from_directory(val_dir,
                                                        target_size=(img_height, img_width),
                                                        batch_size=batch_size,
                                                        class_mode='categorical')

test_generator = test_datagen.flow_from_directory(test_dir,
                                                  target_size=(img_height, img_width),
                                                  batch_size=batch_size,
                                                  class_mode='categorical',
                                                  shuffle=False)
# Define a custom CNN block with fusion of DenseNet and Residual connections
def custom_cnn_block(x, filters):
    input_tensor = x
    # DenseNet-like block
    x1 = layers.Conv2D(filters, (1,1), padding='same', activation='relu')(x)
    x1 = layers.Conv2D(filters, (3,3), padding='same', activation='relu')(x1)
    
    x2 = layers.Conv2D(filters, (1,1), padding='same', activation='relu')(x)
    x2 = layers.Conv2D(filters, (5,5), padding='same', activation='relu')(x2)
    
    x = layers.Concatenate()([x1, x2])
    x = layers.Conv2D(filters, (1,1), padding='same', activation='relu')(x)  # Bottleneck layer
    
    # Residual connection
    shortcut = layers.Conv2D(filters, (1,1), padding='same')(input_tensor)
    x = layers.Add()([x, shortcut])
    x = layers.Activation('relu')(x)
    return x

# Build the model using Functional API
inputs = layers.Input(shape=(img_height, img_width, 3))

# Initial layers
x = layers.Conv2D(32, (3,3), activation='relu', padding='same')(inputs)
x = layers.Conv2D(32, (3,3), activation='relu', padding='same')(x)
x = layers.MaxPooling2D(pool_size=(2,2))(x)
x = inputs
# Custom CNN blocks with increasing filters
x = custom_cnn_block(x, 64)
x = layers.MaxPooling2D(pool_size=(2,2))(x)

x = custom_cnn_block(x, 128)
x = layers.MaxPooling2D(pool_size=(2,2))(x)

# x = custom_cnn_block(x, 256)
# x = layers.MaxPooling2D(pool_size=(2,2))(x)

x = layers.GlobalAveragePooling2D()(x)
x = layers.Dense(256, activation='relu')(x)
x = layers.Dense(128, activation='relu')(x)
# Output layer
outputs = layers.Dense(3, activation='softmax')(x)

# Create the model
model = models.Model(inputs=inputs, outputs=outputs)

# Compile the model
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Print model summary
model.summary()
# Callbacks
early_stopping = tf.keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True, verbose=1)
checkpoint = tf.keras.callbacks.ModelCheckpoint('best_model_wn2.keras', save_best_only=True, monitor='val_loss')
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(factor=0.1, patience=5, min_lr=0.00001)

# Train the model
history = model.fit(train_generator,
                    epochs=10,
                    validation_data=validation_generator,
                    callbacks=[early_stopping, checkpoint, reduce_lr])
# Evaluate on test set
test_loss, test_accuracy = model.evaluate(test_generator)
print(f'Test Accuracy: {test_accuracy:.4f}')

# Predictions
predictions = model.predict(test_generator)
predicted_classes = np.argmax(predictions, axis=1)

# Get true classes
true_classes = test_generator.classes

# Classification report
print('Classification Report:')
print(classification_report(true_classes, predicted_classes, target_names=test_generator.class_indices.keys()))

# Confusion matrix
cm = confusion_matrix(true_classes, predicted_classes)
plt.figure(figsize=(8,6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=test_generator.class_indices.keys(),
            yticklabels=test_generator.class_indices.keys())
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()
# Plot accuracy
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# Plot loss
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# Training set counts: {'Anthracnose': 1080, 'fruit_fly': 918, 'healthy_guava': 649}
# Validation set counts: {'Anthracnose': 308, 'fruit_fly': 262, 'healthy_guava': 185}
# Test set counts: {'Anthracnose': 156, 'fruit_fly': 132, 'healthy_guava': 94}
# Found 2647 images belonging to 3 classes.
# Found 755 images belonging to 3 classes.
# Found 382 images belonging to 3 classes.
# Model: "functional_23"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_13      │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_177 (Conv2D) │ (None, 224, 224,  │        256 │ input_layer_13[0… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_179 (Conv2D) │ (None, 224, 224,  │        256 │ input_layer_13[0… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_178 (Conv2D) │ (None, 224, 224,  │     36,928 │ conv2d_177[0][0]  │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_180 (Conv2D) │ (None, 224, 224,  │    102,464 │ conv2d_179[0][0]  │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_28      │ (None, 224, 224,  │          0 │ conv2d_178[0][0], │
# │ (Concatenate)       │ 128)              │            │ conv2d_180[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_181 (Conv2D) │ (None, 224, 224,  │      8,256 │ concatenate_28[0… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_182 (Conv2D) │ (None, 224, 224,  │        256 │ input_layer_13[0… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_28 (Add)        │ (None, 224, 224,  │          0 │ conv2d_181[0][0], │
# │                     │ 64)               │            │ conv2d_182[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_28       │ (None, 224, 224,  │          0 │ add_28[0][0]      │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_32    │ (None, 112, 112,  │          0 │ activation_28[0]… │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_183 (Conv2D) │ (None, 112, 112,  │      8,320 │ max_pooling2d_32… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_185 (Conv2D) │ (None, 112, 112,  │      8,320 │ max_pooling2d_32… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_184 (Conv2D) │ (None, 112, 112,  │    147,584 │ conv2d_183[0][0]  │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_186 (Conv2D) │ (None, 112, 112,  │    409,728 │ conv2d_185[0][0]  │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_29      │ (None, 112, 112,  │          0 │ conv2d_184[0][0], │
# │ (Concatenate)       │ 256)              │            │ conv2d_186[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_187 (Conv2D) │ (None, 112, 112,  │     32,896 │ concatenate_29[0… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_188 (Conv2D) │ (None, 112, 112,  │      8,320 │ max_pooling2d_32… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_29 (Add)        │ (None, 112, 112,  │          0 │ conv2d_187[0][0], │
# │                     │ 128)              │            │ conv2d_188[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_29       │ (None, 112, 112,  │          0 │ add_29[0][0]      │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_33    │ (None, 56, 56,    │          0 │ activation_29[0]… │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 128)       │          0 │ max_pooling2d_33… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_38 (Dense)    │ (None, 256)       │     33,024 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_39 (Dense)    │ (None, 128)       │     32,896 │ dense_38[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_40 (Dense)    │ (None, 3)         │        387 │ dense_39[0][0]    │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 829,891 (3.17 MB)
#  Trainable params: 829,891 (3.17 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/10
# /opt/conda/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 35s 340ms/step - accuracy: 0.4336 - loss: 0.9780 - val_accuracy: 0.7788 - val_loss: 0.5500 - learning_rate: 0.0010
# Epoch 2/10
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 28s 312ms/step - accuracy: 0.7714 - loss: 0.5399 - val_accuracy: 0.7868 - val_loss: 0.4366 - learning_rate: 0.0010
# Epoch 3/10
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 27s 306ms/step - accuracy: 0.8362 - loss: 0.3937 - val_accuracy: 0.8914 - val_loss: 0.2827 - learning_rate: 0.0010
# Epoch 4/10
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 28s 315ms/step - accuracy: 0.8744 - loss: 0.3158 - val_accuracy: 0.9285 - val_loss: 0.2033 - learning_rate: 0.0010
# Epoch 5/10
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 27s 304ms/step - accuracy: 0.9220 - loss: 0.2045 - val_accuracy: 0.9510 - val_loss: 0.1287 - learning_rate: 0.0010
# Epoch 6/10
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 28s 313ms/step - accuracy: 0.9416 - loss: 0.1528 - val_accuracy: 0.9629 - val_loss: 0.0986 - learning_rate: 0.0010
# Epoch 7/10
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 27s 308ms/step - accuracy: 0.9426 - loss: 0.1444 - val_accuracy: 0.9828 - val_loss: 0.0583 - learning_rate: 0.0010
# Epoch 8/10
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 27s 308ms/step - accuracy: 0.9683 - loss: 0.0934 - val_accuracy: 0.9709 - val_loss: 0.0750 - learning_rate: 0.0010
# Epoch 9/10
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 27s 307ms/step - accuracy: 0.9649 - loss: 0.1183 - val_accuracy: 0.9457 - val_loss: 0.1281 - learning_rate: 0.0010
# Epoch 10/10
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 27s 306ms/step - accuracy: 0.9688 - loss: 0.0979 - val_accuracy: 0.9748 - val_loss: 0.0665 - learning_rate: 0.0010
# Restoring model weights from the end of the best epoch: 7.
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 271ms/step - accuracy: 0.9876 - loss: 0.0466
# Test Accuracy: 0.9738
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 259ms/step
# Classification Report:
#                precision    recall  f1-score   support
#
#   Anthracnose       0.99      1.00      0.99       156
#     fruit_fly       0.96      0.96      0.96       132
# healthy_guava       0.97      0.95      0.96        94
#
#      accuracy                           0.97       382
#     macro avg       0.97      0.97      0.97       382
#  weighted avg       0.97      0.97      0.97       382

# %% [markdown]
# ## BN2 Classifier

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
# Define paths
train_dir = '/kaggle/input/guava-fruit-disease-dataset/Guava Fruit Disease Dataset/GuavaDiseaseDataset/GuavaDiseaseDataset/train'
test_dir = '/kaggle/input/guava-fruit-disease-dataset/Guava Fruit Disease Dataset/GuavaDiseaseDataset/GuavaDiseaseDataset/test'
val_dir = '/kaggle/input/guava-fruit-disease-dataset/Guava Fruit Disease Dataset/GuavaDiseaseDataset/GuavaDiseaseDataset/val'

# Image dimensions
img_height = 224
img_width = 224
batch_size = 32
# Function to count images in each class
def count_images(directory):
    classes = ['Anthracnose', 'fruit_fly', 'healthy_guava']
    counts = {}
    for class_name in classes:
        class_dir = os.path.join(directory, class_name)
        counts[class_name] = len(os.listdir(class_dir))
    return counts

# Count images in train, test, and validation sets
train_counts = count_images(train_dir)
test_counts = count_images(test_dir)
val_counts = count_images(val_dir)

# Print the counts
print("Training set counts:", train_counts)
print("Validation set counts:", val_counts)
print("Test set counts:", test_counts)

# Plot bar chart for training set
plt.bar(train_counts.keys(), train_counts.values())
plt.title('Training Data Distribution')
plt.xlabel('Classes')
plt.ylabel('Number of Images')
plt.show()
# Data generators
train_datagen = ImageDataGenerator(rescale=1./255)

test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(train_dir,
                                                    target_size=(img_height, img_width),
                                                    batch_size=batch_size,
                                                    class_mode='categorical')

validation_generator = test_datagen.flow_from_directory(val_dir,
                                                        target_size=(img_height, img_width),
                                                        batch_size=batch_size,
                                                        class_mode='categorical')

test_generator = test_datagen.flow_from_directory(test_dir,
                                                  target_size=(img_height, img_width),
                                                  batch_size=batch_size,
                                                  class_mode='categorical',
                                                  shuffle=False)
# Define a custom CNN block with fusion of DenseNet and Residual connections
def custom_cnn_block(x, filters):
    input_tensor = x
    # DenseNet-like block
    x1 = layers.Conv2D(filters, (1,1), padding='same', activation='relu')(x)
    x1 = layers.Conv2D(filters, (3,3), padding='same', activation='relu')(x1)
    
    x2 = layers.Conv2D(filters, (1,1), padding='same', activation='relu')(x)
    x2 = layers.Conv2D(filters, (5,5), padding='same', activation='relu')(x2)
    
    x = layers.Concatenate()([x1, x2])
    x = layers.Conv2D(filters, (1,1), padding='same', activation='relu')(x)  # Bottleneck layer
    
    # Residual connection
    shortcut = layers.Conv2D(filters, (1,1), padding='same')(input_tensor)
    x = layers.Add()([x, shortcut])
    x = layers.Activation('relu')(x)
    return x

# Build the model using Functional API
inputs = layers.Input(shape=(img_height, img_width, 3))

# # Initial layers
# x = layers.Conv2D(32, (3,3), activation='relu', padding='same')(inputs)
# x = layers.Conv2D(32, (3,3), activation='relu', padding='same')(x)
# x = layers.MaxPooling2D(pool_size=(2,2))(x)

x = inputs
# Custom CNN blocks with increasing filters
x = custom_cnn_block(x, 64)
x = layers.MaxPooling2D(pool_size=(2,2))(x)

x = custom_cnn_block(x, 128)
x = layers.MaxPooling2D(pool_size=(2,2))(x)

# x = custom_cnn_block(x, 256)
# x = layers.MaxPooling2D(pool_size=(2,2))(x)


x = layers.GlobalAveragePooling2D()(x)
x = layers.Dense(256, activation='relu')(x)
x = layers.BatchNormalization()(x)
x = layers.Dense(128, activation='relu')(x)
# Output layer
outputs = layers.Dense(3, activation='softmax')(x)

# Create the model
model = models.Model(inputs=inputs, outputs=outputs)

# Compile the model
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Print model summary
model.summary()
# Callbacks
early_stopping = tf.keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True, verbose=1)
checkpoint = tf.keras.callbacks.ModelCheckpoint('best_model_bn2.keras', save_best_only=True, monitor='val_loss')
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(factor=0.1, patience=5, min_lr=0.00001)

# Train the model
history = model.fit(train_generator,
                    epochs=10,
                    validation_data=validation_generator,
                    callbacks=[early_stopping, checkpoint, reduce_lr])
# Evaluate on test set
test_loss, test_accuracy = model.evaluate(test_generator)
print(f'Test Accuracy: {test_accuracy:.4f}')

# Predictions
predictions = model.predict(test_generator)
predicted_classes = np.argmax(predictions, axis=1)

# Get true classes
true_classes = test_generator.classes

# Classification report
print('Classification Report:')
print(classification_report(true_classes, predicted_classes, target_names=test_generator.class_indices.keys()))

# Confusion matrix
cm = confusion_matrix(true_classes, predicted_classes)
plt.figure(figsize=(8,6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=test_generator.class_indices.keys(),
            yticklabels=test_generator.class_indices.keys())
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()
# Plot accuracy
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# Plot loss
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# Training set counts: {'Anthracnose': 1080, 'fruit_fly': 918, 'healthy_guava': 649}
# Validation set counts: {'Anthracnose': 308, 'fruit_fly': 262, 'healthy_guava': 185}
# Test set counts: {'Anthracnose': 156, 'fruit_fly': 132, 'healthy_guava': 94}
# Found 2647 images belonging to 3 classes.
# Found 755 images belonging to 3 classes.
# Found 382 images belonging to 3 classes.
# Model: "functional_25"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_14      │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_189 (Conv2D) │ (None, 224, 224,  │        256 │ input_layer_14[0… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_191 (Conv2D) │ (None, 224, 224,  │        256 │ input_layer_14[0… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_190 (Conv2D) │ (None, 224, 224,  │     36,928 │ conv2d_189[0][0]  │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_192 (Conv2D) │ (None, 224, 224,  │    102,464 │ conv2d_191[0][0]  │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_30      │ (None, 224, 224,  │          0 │ conv2d_190[0][0], │
# │ (Concatenate)       │ 128)              │            │ conv2d_192[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_193 (Conv2D) │ (None, 224, 224,  │      8,256 │ concatenate_30[0… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_194 (Conv2D) │ (None, 224, 224,  │        256 │ input_layer_14[0… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_30 (Add)        │ (None, 224, 224,  │          0 │ conv2d_193[0][0], │
# │                     │ 64)               │            │ conv2d_194[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_30       │ (None, 224, 224,  │          0 │ add_30[0][0]      │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_34    │ (None, 112, 112,  │          0 │ activation_30[0]… │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_195 (Conv2D) │ (None, 112, 112,  │      8,320 │ max_pooling2d_34… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_197 (Conv2D) │ (None, 112, 112,  │      8,320 │ max_pooling2d_34… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_196 (Conv2D) │ (None, 112, 112,  │    147,584 │ conv2d_195[0][0]  │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_198 (Conv2D) │ (None, 112, 112,  │    409,728 │ conv2d_197[0][0]  │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_31      │ (None, 112, 112,  │          0 │ conv2d_196[0][0], │
# │ (Concatenate)       │ 256)              │            │ conv2d_198[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_199 (Conv2D) │ (None, 112, 112,  │     32,896 │ concatenate_31[0… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_200 (Conv2D) │ (None, 112, 112,  │      8,320 │ max_pooling2d_34… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_31 (Add)        │ (None, 112, 112,  │          0 │ conv2d_199[0][0], │
# │                     │ 128)              │            │ conv2d_200[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_31       │ (None, 112, 112,  │          0 │ add_31[0][0]      │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_35    │ (None, 56, 56,    │          0 │ activation_31[0]… │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 128)       │          0 │ max_pooling2d_35… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_41 (Dense)    │ (None, 256)       │     33,024 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256)       │      1,024 │ dense_41[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_42 (Dense)    │ (None, 128)       │     32,896 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_43 (Dense)    │ (None, 3)         │        387 │ dense_42[0][0]    │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 830,915 (3.17 MB)
#  Trainable params: 830,403 (3.17 MB)
#  Non-trainable params: 512 (2.00 KB)
# Epoch 1/10
# /opt/conda/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 36s 346ms/step - accuracy: 0.7436 - loss: 0.5605 - val_accuracy: 0.3470 - val_loss: 1.7961 - learning_rate: 0.0010
# Epoch 2/10
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 28s 313ms/step - accuracy: 0.8876 - loss: 0.3151 - val_accuracy: 0.6940 - val_loss: 0.6967 - learning_rate: 0.0010
# Epoch 3/10
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 27s 303ms/step - accuracy: 0.8721 - loss: 0.2984 - val_accuracy: 0.3563 - val_loss: 1.8207 - learning_rate: 0.0010
# Epoch 4/10
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 28s 313ms/step - accuracy: 0.9173 - loss: 0.1951 - val_accuracy: 0.4808 - val_loss: 4.3161 - learning_rate: 0.0010
# Epoch 5/10
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 27s 309ms/step - accuracy: 0.9295 - loss: 0.1641 - val_accuracy: 0.7536 - val_loss: 0.4959 - learning_rate: 0.0010
# Epoch 7/10
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 27s 309ms/step - accuracy: 0.9449 - loss: 0.1354 - val_accuracy: 0.7960 - val_loss: 0.6412 - learning_rate: 0.0010
# Epoch 8/10
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 27s 305ms/step - accuracy: 0.9445 - loss: 0.1437 - val_accuracy: 0.5589 - val_loss: 2.6502 - learning_rate: 0.0010
# Epoch 9/10
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 27s 302ms/step - accuracy: 0.9528 - loss: 0.1270 - val_accuracy: 0.4238 - val_loss: 5.4415 - learning_rate: 0.0010
# Epoch 10/10
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 26s 297ms/step - accuracy: 0.9412 - loss: 0.1547 - val_accuracy: 0.7536 - val_loss: 1.0422 - learning_rate: 0.0010
# Restoring model weights from the end of the best epoch: 6.
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 287ms/step - accuracy: 0.8051 - loss: 0.4234
# Test Accuracy: 0.7487
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 255ms/step
# Classification Report:
#                precision    recall  f1-score   support
#
#   Anthracnose       0.91      0.89      0.90       156
#     fruit_fly       1.00      0.40      0.57       132
# healthy_guava       0.53      1.00      0.69        94
#
#      accuracy                           0.75       382
#     macro avg       0.82      0.76      0.72       382
#  weighted avg       0.85      0.75      0.74       382

# %% [markdown]
# ## MN2 Classifier

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
# Define paths
train_dir = '/kaggle/input/guava-fruit-disease-dataset/Guava Fruit Disease Dataset/GuavaDiseaseDataset/GuavaDiseaseDataset/train'
test_dir = '/kaggle/input/guava-fruit-disease-dataset/Guava Fruit Disease Dataset/GuavaDiseaseDataset/GuavaDiseaseDataset/test'
val_dir = '/kaggle/input/guava-fruit-disease-dataset/Guava Fruit Disease Dataset/GuavaDiseaseDataset/GuavaDiseaseDataset/val'

# Image dimensions
img_height = 224
img_width = 224
batch_size = 32
# Function to count images in each class
def count_images(directory):
    classes = ['Anthracnose', 'fruit_fly', 'healthy_guava']
    counts = {}
    for class_name in classes:
        class_dir = os.path.join(directory, class_name)
        counts[class_name] = len(os.listdir(class_dir))
    return counts

# Count images in train, test, and validation sets
train_counts = count_images(train_dir)
test_counts = count_images(test_dir)
val_counts = count_images(val_dir)

# Print the counts
print("Training set counts:", train_counts)
print("Validation set counts:", val_counts)
print("Test set counts:", test_counts)

# Plot bar chart for training set
plt.bar(train_counts.keys(), train_counts.values())
plt.title('Training Data Distribution')
plt.xlabel('Classes')
plt.ylabel('Number of Images')
plt.show()
# Data generators
train_datagen = ImageDataGenerator(rescale=1./255)

test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(train_dir,
                                                    target_size=(img_height, img_width),
                                                    batch_size=batch_size,
                                                    class_mode='categorical')

validation_generator = test_datagen.flow_from_directory(val_dir,
                                                        target_size=(img_height, img_width),
                                                        batch_size=batch_size,
                                                        class_mode='categorical')

test_generator = test_datagen.flow_from_directory(test_dir,
                                                  target_size=(img_height, img_width),
                                                  batch_size=batch_size,
                                                  class_mode='categorical',
                                                  shuffle=False)
# Define a custom CNN block with fusion of DenseNet and Residual connections
def custom_cnn_block(x, filters):
    input_tensor = x
    # DenseNet-like block
    x1 = layers.Conv2D(filters, (1,1), padding='same', activation='relu')(x)
    x1 = layers.Conv2D(filters, (3,3), padding='same', activation='relu')(x1)
    
    x2 = layers.Conv2D(filters, (1,1), padding='same', activation='relu')(x)
    x2 = layers.Conv2D(filters, (5,5), padding='same', activation='relu')(x2)
    
    x = layers.Concatenate()([x1, x2])
    x = layers.Conv2D(filters, (1,1), padding='same', activation='relu')(x)  # Bottleneck layer
    
    # Residual connection
    shortcut = layers.Conv2D(filters, (1,1), padding='same')(input_tensor)
    x = layers.Add()([x, shortcut])
    x = layers.Activation('relu')(x)
    return x

# Build the model using Functional API
inputs = layers.Input(shape=(img_height, img_width, 3))

# Initial layers
x = layers.Conv2D(32, (3,3), activation='relu', padding='same')(inputs)
x = layers.Conv2D(32, (3,3), activation='relu', padding='same')(x)
x = layers.MaxPooling2D(pool_size=(2,2))(x)

x = inputs
#Custom CNN blocks with increasing filters
x = custom_cnn_block(x, 64)
x = layers.MaxPooling2D(pool_size=(2,2))(x)

x = custom_cnn_block(x, 128)
x = layers.MaxPooling2D(pool_size=(2,2))(x)

# x = custom_cnn_block(x, 256)
# x = layers.MaxPooling2D(pool_size=(2,2))(x)


x = layers.GlobalAveragePooling2D()(x)
x = layers.Dense(256, activation='relu')(x)
x = layers.Dropout(0.5)(x) 
x = layers.Dense(128, activation='relu')(x)
# Output layer
outputs = layers.Dense(3, activation='softmax')(x)

# Create the model
model = models.Model(inputs=inputs, outputs=outputs)

# Compile the model
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Print model summary
model.summary()
# Callbacks
early_stopping = tf.keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True, verbose=1)
checkpoint = tf.keras.callbacks.ModelCheckpoint('best_model_mn2.keras', save_best_only=True, monitor='val_loss')
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(factor=0.1, patience=5, min_lr=0.00001)

# Train the model
history = model.fit(train_generator,
                    epochs=10,
                    validation_data=validation_generator,
                    callbacks=[early_stopping, checkpoint, reduce_lr])
# Evaluate on test set
test_loss, test_accuracy = model.evaluate(test_generator)
print(f'Test Accuracy: {test_accuracy:.4f}')

# Predictions
predictions = model.predict(test_generator)
predicted_classes = np.argmax(predictions, axis=1)

# Get true classes
true_classes = test_generator.classes

# Classification report
print('Classification Report:')
print(classification_report(true_classes, predicted_classes, target_names=test_generator.class_indices.keys()))

# Confusion matrix
cm = confusion_matrix(true_classes, predicted_classes)
plt.figure(figsize=(8,6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=test_generator.class_indices.keys(),
            yticklabels=test_generator.class_indices.keys())
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()
# Plot accuracy
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# Plot loss
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# Training set counts: {'Anthracnose': 1080, 'fruit_fly': 918, 'healthy_guava': 649}
# Validation set counts: {'Anthracnose': 308, 'fruit_fly': 262, 'healthy_guava': 185}
# Test set counts: {'Anthracnose': 156, 'fruit_fly': 132, 'healthy_guava': 94}
# Found 2647 images belonging to 3 classes.
# Found 755 images belonging to 3 classes.
# Found 382 images belonging to 3 classes.
# Model: "functional_27"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_15      │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_203 (Conv2D) │ (None, 224, 224,  │        256 │ input_layer_15[0… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_205 (Conv2D) │ (None, 224, 224,  │        256 │ input_layer_15[0… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_204 (Conv2D) │ (None, 224, 224,  │     36,928 │ conv2d_203[0][0]  │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_206 (Conv2D) │ (None, 224, 224,  │    102,464 │ conv2d_205[0][0]  │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_32      │ (None, 224, 224,  │          0 │ conv2d_204[0][0], │
# │ (Concatenate)       │ 128)              │            │ conv2d_206[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_207 (Conv2D) │ (None, 224, 224,  │      8,256 │ concatenate_32[0… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_208 (Conv2D) │ (None, 224, 224,  │        256 │ input_layer_15[0… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_32 (Add)        │ (None, 224, 224,  │          0 │ conv2d_207[0][0], │
# │                     │ 64)               │            │ conv2d_208[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_32       │ (None, 224, 224,  │          0 │ add_32[0][0]      │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_37    │ (None, 112, 112,  │          0 │ activation_32[0]… │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_209 (Conv2D) │ (None, 112, 112,  │      8,320 │ max_pooling2d_37… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_211 (Conv2D) │ (None, 112, 112,  │      8,320 │ max_pooling2d_37… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_210 (Conv2D) │ (None, 112, 112,  │    147,584 │ conv2d_209[0][0]  │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_212 (Conv2D) │ (None, 112, 112,  │    409,728 │ conv2d_211[0][0]  │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_33      │ (None, 112, 112,  │          0 │ conv2d_210[0][0], │
# │ (Concatenate)       │ 256)              │            │ conv2d_212[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_213 (Conv2D) │ (None, 112, 112,  │     32,896 │ concatenate_33[0… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_214 (Conv2D) │ (None, 112, 112,  │      8,320 │ max_pooling2d_37… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_33 (Add)        │ (None, 112, 112,  │          0 │ conv2d_213[0][0], │
# │                     │ 128)              │            │ conv2d_214[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_33       │ (None, 112, 112,  │          0 │ add_33[0][0]      │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_38    │ (None, 56, 56,    │          0 │ activation_33[0]… │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 128)       │          0 │ max_pooling2d_38… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_44 (Dense)    │ (None, 256)       │     33,024 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 256)       │          0 │ dense_44[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_45 (Dense)    │ (None, 128)       │     32,896 │ dropout_3[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_46 (Dense)    │ (None, 3)         │        387 │ dense_45[0][0]    │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 829,891 (3.17 MB)
#  Trainable params: 829,891 (3.17 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/10
# /opt/conda/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 39s 362ms/step - accuracy: 0.4096 - loss: 1.0254 - val_accuracy: 0.7457 - val_loss: 0.5939 - learning_rate: 0.0010
# Epoch 2/10
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 28s 314ms/step - accuracy: 0.7246 - loss: 0.6209 - val_accuracy: 0.8358 - val_loss: 0.4151 - learning_rate: 0.0010
# Epoch 3/10
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 28s 321ms/step - accuracy: 0.8128 - loss: 0.4656 - val_accuracy: 0.8464 - val_loss: 0.3780 - learning_rate: 0.0010
# Epoch 4/10
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 28s 318ms/step - accuracy: 0.8722 - loss: 0.3160 - val_accuracy: 0.9232 - val_loss: 0.1667 - learning_rate: 0.0010
# Epoch 5/10
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 28s 317ms/step - accuracy: 0.9370 - loss: 0.2015 - val_accuracy: 0.9430 - val_loss: 0.1598 - learning_rate: 0.0010
# Epoch 6/10
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 29s 327ms/step - accuracy: 0.9402 - loss: 0.1873 - val_accuracy: 0.9536 - val_loss: 0.1488 - learning_rate: 0.0010
# Epoch 7/10
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 30s 331ms/step - accuracy: 0.9399 - loss: 0.1637 - val_accuracy: 0.9815 - val_loss: 0.0698 - learning_rate: 0.0010
# Epoch 8/10
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 29s 323ms/step - accuracy: 0.9545 - loss: 0.1172 - val_accuracy: 0.9576 - val_loss: 0.0980 - learning_rate: 0.0010
# Epoch 9/10
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 29s 321ms/step - accuracy: 0.9612 - loss: 0.1143 - val_accuracy: 0.9642 - val_loss: 0.0813 - learning_rate: 0.0010
# Epoch 10/10
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 28s 313ms/step - accuracy: 0.9508 - loss: 0.1271 - val_accuracy: 0.9166 - val_loss: 0.2551 - learning_rate: 0.0010
# Restoring model weights from the end of the best epoch: 7.
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 273ms/step - accuracy: 0.9832 - loss: 0.0581
# Test Accuracy: 0.9634
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 251ms/step
# Classification Report:
#                precision    recall  f1-score   support
#
#   Anthracnose       0.98      1.00      0.99       156
#     fruit_fly       0.96      0.94      0.95       132
# healthy_guava       0.94      0.94      0.94        94
#
#      accuracy                           0.96       382
#     macro avg       0.96      0.96      0.96       382
#  weighted avg       0.96      0.96      0.96       382

# %% [markdown]
# ## TN2 Classifier

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
# Define paths
train_dir = '/kaggle/input/guava-fruit-disease-dataset/Guava Fruit Disease Dataset/GuavaDiseaseDataset/GuavaDiseaseDataset/train'
test_dir = '/kaggle/input/guava-fruit-disease-dataset/Guava Fruit Disease Dataset/GuavaDiseaseDataset/GuavaDiseaseDataset/test'
val_dir = '/kaggle/input/guava-fruit-disease-dataset/Guava Fruit Disease Dataset/GuavaDiseaseDataset/GuavaDiseaseDataset/val'

# Image dimensions
img_height = 224
img_width = 224
batch_size = 32
# Function to count images in each class
def count_images(directory):
    classes = ['Anthracnose', 'fruit_fly', 'healthy_guava']
    counts = {}
    for class_name in classes:
        class_dir = os.path.join(directory, class_name)
        counts[class_name] = len(os.listdir(class_dir))
    return counts

# Count images in train, test, and validation sets
train_counts = count_images(train_dir)
test_counts = count_images(test_dir)
val_counts = count_images(val_dir)

# Print the counts
print("Training set counts:", train_counts)
print("Validation set counts:", val_counts)
print("Test set counts:", test_counts)

# Plot bar chart for training set
plt.bar(train_counts.keys(), train_counts.values())
plt.title('Training Data Distribution')
plt.xlabel('Classes')
plt.ylabel('Number of Images')
plt.show()
# Data generators
train_datagen = ImageDataGenerator(rescale=1./255)

test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(train_dir,
                                                    target_size=(img_height, img_width),
                                                    batch_size=batch_size,
                                                    class_mode='categorical')

validation_generator = test_datagen.flow_from_directory(val_dir,
                                                        target_size=(img_height, img_width),
                                                        batch_size=batch_size,
                                                        class_mode='categorical')

test_generator = test_datagen.flow_from_directory(test_dir,
                                                  target_size=(img_height, img_width),
                                                  batch_size=batch_size,
                                                  class_mode='categorical',
                                                  shuffle=False)
# Define a custom CNN block with fusion of DenseNet and Residual connections
def custom_cnn_block(x, filters):
    input_tensor = x
    # DenseNet-like block
    x1 = layers.Conv2D(filters, (1,1), padding='same', activation='relu')(x)
    x1 = layers.Conv2D(filters, (3,3), padding='same', activation='relu')(x1)
    
    x2 = layers.Conv2D(filters, (1,1), padding='same', activation='relu')(x)
    x2 = layers.Conv2D(filters, (5,5), padding='same', activation='relu')(x2)
    
    x = layers.Concatenate()([x1, x2])
    x = layers.Conv2D(filters, (1,1), padding='same', activation='relu')(x)  # Bottleneck layer
    
    # Residual connection
    shortcut = layers.Conv2D(filters, (1,1), padding='same')(input_tensor)
    x = layers.Add()([x, shortcut])
    x = layers.Activation('relu')(x)
    return x

# Build the model using Functional API
inputs = layers.Input(shape=(img_height, img_width, 3))

# Initial layers
x = layers.Conv2D(32, (3,3), activation='relu', padding='same')(inputs)
x = layers.Conv2D(32, (3,3), activation='relu', padding='same')(x)
x = layers.MaxPooling2D(pool_size=(2,2))(x)
x = inputs
# Custom CNN blocks with increasing filters
x = custom_cnn_block(x, 64)
x = layers.MaxPooling2D(pool_size=(2,2))(x)

x = custom_cnn_block(x, 128)
x = layers.MaxPooling2D(pool_size=(2,2))(x)

# x = custom_cnn_block(x, 256)
# x = layers.MaxPooling2D(pool_size=(2,2))(x)


x = layers.GlobalAveragePooling2D()(x)
x = layers.Dense(128, activation='relu')(x)
x = layers.Dense(64, activation='relu')(x)
# Output layer
outputs = layers.Dense(3, activation='softmax')(x)

# Create the model
model = models.Model(inputs=inputs, outputs=outputs)

# Compile the model
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Print model summary
model.summary()
# Callbacks
early_stopping = tf.keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True, verbose=1)
checkpoint = tf.keras.callbacks.ModelCheckpoint('best_model_tn2.keras', save_best_only=True, monitor='val_loss')
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(factor=0.1, patience=5, min_lr=0.00001)

# Train the model
history = model.fit(train_generator,
                    epochs=10,
                    validation_data=validation_generator,
                    callbacks=[early_stopping, checkpoint, reduce_lr])
# Evaluate on test set
test_loss, test_accuracy = model.evaluate(test_generator)
print(f'Test Accuracy: {test_accuracy:.4f}')

# Predictions
predictions = model.predict(test_generator)
predicted_classes = np.argmax(predictions, axis=1)

# Get true classes
true_classes = test_generator.classes

# Classification report
print('Classification Report:')
print(classification_report(true_classes, predicted_classes, target_names=test_generator.class_indices.keys()))

# Confusion matrix
cm = confusion_matrix(true_classes, predicted_classes)
plt.figure(figsize=(8,6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=test_generator.class_indices.keys(),
            yticklabels=test_generator.class_indices.keys())
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()
# Plot accuracy
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# Plot loss
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# Training set counts: {'Anthracnose': 1080, 'fruit_fly': 918, 'healthy_guava': 649}
# Validation set counts: {'Anthracnose': 308, 'fruit_fly': 262, 'healthy_guava': 185}
# Test set counts: {'Anthracnose': 156, 'fruit_fly': 132, 'healthy_guava': 94}
# Found 2647 images belonging to 3 classes.
# Found 755 images belonging to 3 classes.
# Found 382 images belonging to 3 classes.
# Model: "functional_31"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_17      │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_231 (Conv2D) │ (None, 224, 224,  │        256 │ input_layer_17[0… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_233 (Conv2D) │ (None, 224, 224,  │        256 │ input_layer_17[0… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_232 (Conv2D) │ (None, 224, 224,  │     36,928 │ conv2d_231[0][0]  │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_234 (Conv2D) │ (None, 224, 224,  │    102,464 │ conv2d_233[0][0]  │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_36      │ (None, 224, 224,  │          0 │ conv2d_232[0][0], │
# │ (Concatenate)       │ 128)              │            │ conv2d_234[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_235 (Conv2D) │ (None, 224, 224,  │      8,256 │ concatenate_36[0… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_236 (Conv2D) │ (None, 224, 224,  │        256 │ input_layer_17[0… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_36 (Add)        │ (None, 224, 224,  │          0 │ conv2d_235[0][0], │
# │                     │ 64)               │            │ conv2d_236[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_36       │ (None, 224, 224,  │          0 │ add_36[0][0]      │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_43    │ (None, 112, 112,  │          0 │ activation_36[0]… │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_237 (Conv2D) │ (None, 112, 112,  │      8,320 │ max_pooling2d_43… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_239 (Conv2D) │ (None, 112, 112,  │      8,320 │ max_pooling2d_43… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_238 (Conv2D) │ (None, 112, 112,  │    147,584 │ conv2d_237[0][0]  │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_240 (Conv2D) │ (None, 112, 112,  │    409,728 │ conv2d_239[0][0]  │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_37      │ (None, 112, 112,  │          0 │ conv2d_238[0][0], │
# │ (Concatenate)       │ 256)              │            │ conv2d_240[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_241 (Conv2D) │ (None, 112, 112,  │     32,896 │ concatenate_37[0… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_242 (Conv2D) │ (None, 112, 112,  │      8,320 │ max_pooling2d_43… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_37 (Add)        │ (None, 112, 112,  │          0 │ conv2d_241[0][0], │
# │                     │ 128)              │            │ conv2d_242[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_37       │ (None, 112, 112,  │          0 │ add_37[0][0]      │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_44    │ (None, 56, 56,    │          0 │ activation_37[0]… │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 128)       │          0 │ max_pooling2d_44… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_50 (Dense)    │ (None, 128)       │     16,512 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_51 (Dense)    │ (None, 64)        │      8,256 │ dense_50[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_52 (Dense)    │ (None, 3)         │        195 │ dense_51[0][0]    │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 788,547 (3.01 MB)
#  Trainable params: 788,547 (3.01 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/10
# /opt/conda/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 35s 343ms/step - accuracy: 0.4296 - loss: 1.0039 - val_accuracy: 0.6715 - val_loss: 0.6612 - learning_rate: 0.0010
# Epoch 2/10
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 28s 312ms/step - accuracy: 0.7053 - loss: 0.6352 - val_accuracy: 0.7868 - val_loss: 0.5020 - learning_rate: 0.0010
# Epoch 3/10
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 28s 315ms/step - accuracy: 0.7632 - loss: 0.5368 - val_accuracy: 0.8291 - val_loss: 0.3881 - learning_rate: 0.0010
# Epoch 4/10
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 27s 308ms/step - accuracy: 0.8507 - loss: 0.3868 - val_accuracy: 0.8543 - val_loss: 0.3338 - learning_rate: 0.0010
# Epoch 5/10
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 28s 310ms/step - accuracy: 0.8882 - loss: 0.2966 - val_accuracy: 0.9338 - val_loss: 0.1729 - learning_rate: 0.0010
# Epoch 6/10
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 28s 311ms/step - accuracy: 0.9246 - loss: 0.2032 - val_accuracy: 0.8742 - val_loss: 0.2915 - learning_rate: 0.0010
# Epoch 7/10
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 28s 312ms/step - accuracy: 0.9338 - loss: 0.1769 - val_accuracy: 0.9616 - val_loss: 0.1146 - learning_rate: 0.0010
# Epoch 8/10
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 28s 312ms/step - accuracy: 0.9521 - loss: 0.1345 - val_accuracy: 0.9377 - val_loss: 0.1334 - learning_rate: 0.0010
# Epoch 9/10
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 28s 312ms/step - accuracy: 0.9563 - loss: 0.1164 - val_accuracy: 0.9695 - val_loss: 0.0841 - learning_rate: 0.0010
# Epoch 10/10
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 27s 307ms/step - accuracy: 0.9648 - loss: 0.0922 - val_accuracy: 0.9868 - val_loss: 0.0553 - learning_rate: 0.0010
# Restoring model weights from the end of the best epoch: 10.
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 278ms/step - accuracy: 0.9929 - loss: 0.0296
# Test Accuracy: 0.9817
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 253ms/step
# Classification Report:
#                precision    recall  f1-score   support
#
#   Anthracnose       0.99      1.00      0.99       156
#     fruit_fly       0.96      0.99      0.98       132
# healthy_guava       1.00      0.94      0.97        94
#
#      accuracy                           0.98       382
#     macro avg       0.98      0.98      0.98       382
#  weighted avg       0.98      0.98      0.98       382
